# %%
# !pip install pymongo
# !pip install cssselect
import re
import time
from typing import Iterator
import requests
import lxml.html
from pymongo import MongoClient

def main():
    """
    crawlerのメイン処理
    """
    client = MongoClient('localhost', 27017)
    collection = client.scraping.ebooks #scrapingデータベースの、ebooksコレクションを取ってくる
    collection.create_index('key', unique = True) #key fieldにuniqueなindexを作成する

    session = requests.Session()
    res = session.get('https://gihyo.jp/dp')
    urls = scrape_list_page(res)
    for url in urls:
        key = extract_key(url) #urlからキーを取得する
        ebook = collection.find_one(
            {'key': key}
        ) #DBから、keyに該当するデータを探す。
        if ebook is None: #存在しない場合だけ、詳細ページをクロールする
            time.sleep(1)
            res = session.get(url)
            ebook = scrape_detail_page(res)
            collection.insert_one(ebook)
        print(ebook)

def scrape_list_page(res):
    """
    一覧ページ（元）から、詳細ページのurlを抜き出す
    """
    html = lxml.html.fromstring(res.text) #.fromstring()関数
    html.make_links_absolute(res.url) #引数のurlに対しての絶対リンクを作る
    a_link = html.cssselect('#listBook > li > a[itemprop="url"]')
    for a in a_link:
        url = a.get('href')
        yield url

def scrape_detail_page(res):
    """
    詳細ページのresから書籍の情報を取得、dictに格納する
    """
    html = lxml.html.fromstring(res.text)
    ebook = {
        'url': res.url, #url
        'key': extract_key(res.url), #urlからキーを抜き出す
        'title': html.cssselect('#bookTitle')[0].text_content(),
        'price': html.cssselect('.buy')[0].text.strip(),
        'content': [normalize_spaces(h3.text_content()) for h3 in html.cssselect('#content > h3')]
    }
    return ebook

def extract_key(url):
    """
    urlからキーを抜き出す
    """
    m = re.search(r'/([^/]+)$', url)
    return m.group(1)

def normalize_spaces(s):
    """
    連続する空白を一つのスペースに置き換え、前後の空白を削除した新しい文字列を取得する。
    """
    return re.sub(r'\s+', ' ', s).strip()

if __name__ == '__main__':
    main()
# Out:
# Requirement already satisfied: pymongo in ./opt/anaconda3/lib/python3.8/site-packages (4.1.1)
# Requirement already satisfied: cssselect in ./opt/anaconda3/lib/python3.8/site-packages (1.1.0)
# {'_id': ObjectId('62a9c95d918df2dec06e2625'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12863-0', 'key': '978-4-297-12863-0', 'title': 'スマホではじめるビデオ会議 Zoom & Microsoft Teams［iPhone & Android対応版］', 'price': '1,200円', 'content': ['第1章 ビデオ会議の基本', '第2章 Zoomでビデオ会議に参加しよう', '第3章 Zoomでビデオ会議を開こう', '第4章 Microsoft Teamsでビデオ会議に参加しよう', '第5章 Microsoft Teamsでビデオ会議を開こう', '第6章 ビデオ会議で困ったときのQ&A']}
# {'_id': ObjectId('62a9c95f918df2dec06e2626'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12887-6', 'key': '978-4-297-12887-6', 'title': '「微」「積」で鍛える数学的思考～分けて集める本当の意味がわかる～', 'price': '2,400円', 'content': ['第1章 数学的思考論', '第2章 微分法の基礎の基礎', '第3章 微分法の基礎・基本', '第4章 微分法の発展', '第5章 微分法の応用', '第6章 積分法の基礎', '第7章 積分法の基本', '第8章 積分法の発展', '第9章 積分法の応用', '第10章 微分法と積分法のさらなる応用']}
# {'_id': ObjectId('62a9c960918df2dec06e2627'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12859-3', 'key': '978-4-297-12859-3', 'title': '図解即戦力工作機械業界のしくみとビジネスがこれ1冊でしっかりわかる教科書', 'price': '1,500円', 'content': ['Chapter 1 ものづくりを支える工作機械', 'Chapter 2 工作機械の種類・サービス', 'Chapter 3 工作機械業界のビジネスモデル', 'Chapter 4 工作機械業界に求められる人材', 'Chapter 5 工作機械業界の主要メーカー', 'Chapter 6 世界の工作機械産業', 'Chapter 7 工作機械業界の技術トレンド', 'Chapter 8 工作機械業界の展望']}
# {'_id': ObjectId('62a9c961918df2dec06e2628'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12906-4', 'key': '978-4-297-12906-4', 'title': 'プロジェクトマネジメントの基本がこれ1冊でしっかり身につく本', 'price': '2,200円', 'content': ['第1章 プロジェクトマネジメントの基本', '第2章 プロジェクトの立ち上げ', '第3章 プロジェクトの計画立案', '第4章 プロジェクト実行・組織作り・コミュニケーション', '第5章 プロジェクトの監視・コントロール', '第6章 プロジェクトの完了']}
# {'_id': ObjectId('62a9c962918df2dec06e2629'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12734-3', 'key': '978-4-297-12734-3', 'title': 'Software Design 2022年7月号', 'price': '1,342円', 'content': ['第1特集 Vimの基本大全 どんな状況でも通用するviの使い方からしっかりと！', '第2特集 ソフトウェア開発のシン常識 ツール，設計，開発スタイルからの多面チェック', '一般記事', '連載']}
# {'_id': ObjectId('62a9c964918df2dec06e262a'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12908-8', 'key': '978-4-297-12908-8', 'title': '基礎からのWeb開発リテラシー', 'price': '2,300円', 'content': ['第1章 Webの概要', '第2章 Webサイトの構成', '第3章 Webサーバーへの配置', '第4章 Webに関するネットワーク', '第5章 Webのセキュリティ', '第6章 ECサイトの設計と運用', '第7章 ECサイト制作に求められる知識']}
# {'_id': ObjectId('62a9c965918df2dec06e262b'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12875-3', 'key': '978-4-297-12875-3', 'title': '令和04年【秋期】 応用情報技術者 パーフェクトラーニング過去問題集', 'price': '1,880円', 'content': ['①令和4年度【春期】', '②令和03年度【秋期】', '③令和3年度【春期】', '④令和2年度【秋期】']}
# {'_id': ObjectId('62a9c966918df2dec06e262c'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12827-2', 'key': '978-4-297-12827-2', 'title': '令和04年【下半期】 ITパスポート パーフェクトラーニング過去問題集', 'price': '1,180円', 'content': ['巻頭記事', '公開問題＋模擬問題と詳細解説']}
# {'_id': ObjectId('62a9c967918df2dec06e262d'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12853-1', 'key': '978-4-297-12853-1', 'title': '図解でやさしくわかる ネットワークのしくみ超入門', 'price': '1,800円', 'content': ['第1章 ネットワークを学ぼう', '第2章 データはネットワークをどう流れる？', '第3章 ネットワークモデルを知ろう', '第4章 ネットワークモデルのプロトコルを知ろう', '第5章 ネットワーク内のサーバーの働きを知ろう', '第6章 ネットワークの管理と運用を学ぼう', '第7章 ネットワークのセキュリティを強化しよう', '第8章 ネットワークの広がり']}
# {'_id': ObjectId('62a9c969918df2dec06e262e'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12861-6', 'key': '978-4-297-12861-6', 'title': 'ゼロからはじめるApple Watch アプリ 完全大事典', 'price': '1,500円', 'content': ['第1章 Apple Watchの使い方', '第2章 定番アプリ', '第3章 健康', '第4章 お出かけ／旅行', '第5章 くらし', '第6章 ビジネス', '第7章 便利ツール', '第8章 写真／音楽', '第9章 学習', '第10章 ゲーム']}
# {'_id': ObjectId('62a9c96a918df2dec06e262f'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12814-2', 'key': '978-4-297-12814-2', 'title': '60分でわかる！暗号資産 超入門', 'price': '1,200円', 'content': ['Part1 ビットコインの枠を超える ～投機から実用へ！暗号資産の最前線', 'Part2 ブームを超えて注目される理由 ～暗号資産を読み解く7つの視点', 'Part3 お金の成り立ちから探る ～暗号資産は「通貨」となるのか', 'Part4 マーケットでの売買のしくみ ～暗号資産の取引方法を知ろう', 'Part5 デジタル・コンテンツの流通を変える ～暗号資産／NFT技術とはなにか？', 'Part6 暗号資産の枠を超えて広がる ～ブロックチェーンが社会を変える', 'Part7 リスクと将来性を正しく理解する ～暗号資産の課題と未来']}
# {'_id': ObjectId('62a9c96b918df2dec06e2630'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12835-7', 'key': '978-4-297-12835-7', 'title': '「棒人間」からはじめる キャラの描き方 超入門', 'price': '1,800円', 'content': ['第1章 キャラクターの描き方を知ろう', '第2章 棒人間を描こう', '第3章 棒人間に肉付けしよう', '第4章 キャラクターを描こう バストアップ編', '第5章 キャラクターを描こう 全身編', '第6章 キャラクターの描き分け方を知ろう']}
# {'_id': ObjectId('62a9c96c918df2dec06e2631'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12883-8', 'key': '978-4-297-12883-8', 'title': '子どもたちの未来を創ったプログラミング教育～日本最初のプログラミング教育を受けた小学生たちは一世代後にどう育ったか、プログラミングが育てた思考・創造力～', 'price': '1,800円', 'content': ['第1章 30年後の宿題 ―教え子追跡調査プロジェクトのはじまり―', '第2章 最後のミッション', '第3章 9つのプログラミングの物語 ―アルゴリズム算数・プログラミング理科―', '第4章 プログラミングに優れた子どもたちの謎', '第5章 「小さな研究室」の発見 ― 一斉授業との決別―', '第6章 論理の誕生 ―プログラミング教育が育むもの―', '第7章 プログラミング教育の根源I ―元小学校教師の哲学者，ウィトゲンシュタインが考えたこと―', '第8章 プログラミング教育の根源II ―プログラミング教育の父，パパートが考えたこと―', '第9章 学びをつれてくる「道具」 ―AIと子どもたちとの関わり―', '第10章 先生がくれた未来へのバトン']}
# {'_id': ObjectId('62a9c96d918df2dec06e2632'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12839-5', 'key': '978-4-297-12839-5', 'title': '大きな字でわかりやすいYouTube ユーチューブ入門', 'price': '1,480円', 'content': ['第1章 YouTubeの基本について理解しよう', '第2章 動画を視聴しよう', '第3章 動画をまとめて管理しよう', '第4章 見たい動画を検索しよう', '第5章 自分のチャンネルを作成しよう', '第6章 自分の動画を投稿しよう', '第7章 スマホやタブレットで視聴しよう']}
# {'_id': ObjectId('62a9c96f918df2dec06e2633'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12845-6', 'key': '978-4-297-12845-6', 'title': '今すぐ使えるかんたんGoogle for Education～導入から運用まで、一冊でしっかりわかる本～', 'price': '2,200円', 'content': ['第1章 Google for Education の基本を知ろう', '第2章 Chromebook を利用しよう', '第3章 Google Workspace for Education を知ろう', '第4章 Google Classroom を設定・準備しよう', '第5章 Google Classroom を活用しよう', '第6章 Google アプリを活用しよう', '第7章 保護者とコミュニケーションを取ろう', '第8章 Google for Education の担当者・管理者の心得を学ぼう', '付録1 管理コンソールの使い方', '付録2 お悩み解決Q＆A']}
# {'_id': ObjectId('62a9c970918df2dec06e2634'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12885-2', 'key': '978-4-297-12885-2', 'title': 'こっそり楽しむうんこ化石の世界', 'price': '2,200円', 'content': ['第1章 ティラノサウルスの「うんこ」。「うんこ」も化石になる！', '第2章 「うんこ」はどこから「うんこ」なのか', '第3章 さまざまな「うんこの化石」', '第4章 “トイレ”の重要性', '第5章 「うんこの化石」の起源', '第6章 「うんこ化石」と世界', '終章 うんこが残した世界']}
# {'_id': ObjectId('62a9c971918df2dec06e2635'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12849-4', 'key': '978-4-297-12849-4', 'title': '今すぐ使えるかんたんExMicrosoft Teams プロ技BESTセレクション', 'price': '1,680円', 'content': ['第1章 Teamsの基本', '第2章 チームを使いこなすプロ技', '第3章 チャネルを使いこなすプロ技', '第4章 メッセージやチャットを使いこなすプロ技', '第5章 ビデオ会議を使いこなすプロ技', '第6章 MSアプリ連携のプロ技', '第7章 Teamsをさらに使いこなすプロ技', '第8章 スマートフォンやタブレットでのプロ技']}
# {'_id': ObjectId('62a9c973918df2dec06e2636'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12847-0', 'key': '978-4-297-12847-0', 'title': '達人が教えるWebパフォーマンスチューニング〜ISUCONから学ぶ高速化の実践', 'price': '2,980円', 'content': ['Chapter1 チューニングの基礎知識', 'Chapter2 モニタリング', 'Chapter3 基礎的な負荷試験', 'Chapter4 シナリオを持った負荷試験', 'Chapter5 データベースのチューニング', 'Chapter6 リバースプロキシの利用', 'Chapter7 キャッシュの活用', 'Chapter8 押さえておきたい高速化手法', 'Chapter9 OSの基礎知識とチューニング', '付録']}
# {'_id': ObjectId('62a9c974918df2dec06e2637'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12843-2', 'key': '978-4-297-12843-2', 'title': 'ゼロからはじめるFacebook フェイスブック 基本＆便利技', 'price': '1,380円', 'content': ['Chapter1 Facebookを始めよう', 'Chapter2 Facebookに投稿してみよう', 'Chapter3 写真や動画を投稿して楽しもう', 'Chapter4 友達ともっとコミュニケーションしよう', 'Chapter5 Facebookをもっと使いやすくしよう', 'Chapter6 こんなときどうする？']}
# {'_id': ObjectId('62a9c975918df2dec06e2638'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12857-9', 'key': '978-4-297-12857-9', 'title': '図解即戦力機械業界のしくみとビジネスがこれ1冊でしっかりわかる教科書', 'price': '1,500円', 'content': ['Chapter 01 機械業界の市場動向', 'Chapter 02 機械業界の全体像', 'Chapter 03 機械業界の各分野の基礎知識', 'Chapter 04 機械業界のグローバル化と海外における動向', 'Chapter 05 機械業界の主要企業とその動向', 'Chapter 06 機械業界の仕事', 'Chapter 07 機械業界の課題と今後の方向性']}
# {'_id': ObjectId('62a9c977918df2dec06e2639'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12829-6', 'key': '978-4-297-12829-6', 'title': '分析が導く 最新SEOプラクティカルガイド', 'price': '2,400円', 'content': ['第1章 商品とユーザーの現状を分析する', '第2章 適切な施策を選択する', '第3章 自身のウェブサイトの現状と課題を把握する', '第4章 競合とターゲット検索ユーザーの状況を調べる', '第5章 検討した施策と分析をもとにコンテンツ作成のプランを練る', '第6章 コンテンツライティング', '第7章 オンページSEO', '第8章 ローカルSEO', '第9章 テクニカルなSEO', '第10章 被リンクの獲得と活用方法', '第11章 検索順位の計測方法と改善施策', '第12章 そのほか定期的に監視すべき指標と施策への応用', '第13章 初期の計画達成後の取り組み']}
# {'_id': ObjectId('62a9c978918df2dec06e263a'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12796-1', 'key': '978-4-297-12796-1', 'title': 'スピードマスターAccessデータベース 用語図鑑', 'price': '1,000円', 'content': ['第1章 データベース概要', '第2章 Accessを使う前に', '第3章 テーブルの基礎知識', '第4章 テーブルの内容を操作する', '第5章 テーブル', '第6章 クエリ', '第7章 レポート&フォーム', '第8章 自動化']}
# {'_id': ObjectId('62a9c979918df2dec06e263b'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12831-9', 'key': '978-4-297-12831-9', 'title': '動画の文法～トップ・プロが教える「伝わる動画」の作り方', 'price': '2,980円', 'content': ['Chapter1 編集と文法', 'Chapter2 コラージュとモンタージュ', 'Chapter3 ストーリーをつづるために', 'Chapter4 カメラの都合', 'Chapter5 編集の禁止事項（やってはいけない編集とその回避の仕方）', 'Chapter6 基本を超えた編集技法', 'Chapter7 動画の種類と特性', 'Chapter8 言葉について', 'Chapter9 動画の周辺知識']}
# {'_id': ObjectId('62a9c97b918df2dec06e263c'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12792-3', 'key': '978-4-297-12792-3', 'title': '今すぐ使えるかんたんOffice for Mac［Office 2021/Microsoft 365両対応］', 'price': '2,400円', 'content': ['第0章 Office 2021の基本操作をマスターしよう', '第1章 Excelの基本操作をマスターしよう', '第2章 Excelをもっと便利に活用しよう', '第3章 Wordの基本操作をマスターしよう', '第4章 Wordをもっと便利に活用しよう', '第5章 PowerPointの操作をマスターしよう', '第6章 Outlookの操作をマスターしよう', '第7章 OneDriveの操作をマスターしよう', '付録']}
# {'_id': ObjectId('62a9c97c918df2dec06e263d'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12733-6', 'key': '978-4-297-12733-6', 'title': 'Software Design 2022年6月号', 'price': '1,342円', 'content': ['第1特集シェルの基本大全どんな環境でも迷わない・困らない知識', '第2特集後悔しないAWSデータベースの選び方RDSとDynamoDB，使い分けのポイントを徹底解説', '第3特集不思議の国のSE用語一人前のエンジニアになる方法', '一般記事', '連載']}
# {'_id': ObjectId('62a9c97d918df2dec06e263e'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12808-1', 'key': '978-4-297-12808-1', 'title': '図解即戦力自動車業界のしくみとビジネスがこれ1冊でしっかりわかる教科書', 'price': '1,500円', 'content': ['Chapter 1 自動車業界の基礎知識', 'Chapter 2 自動車業界の最新動向', 'Chapter 3 日本国内の主要自動車メーカー', 'Chapter 4 自動車メーカーの仕事', 'Chapter 5 自動車の販売', 'Chapter 6 自動車部品・素材', 'Chapter 7 自動車関連サービス', 'Chapter 8 自動車メーカーの海外進出', 'Chapter 9 自動車の関連法令・規則', 'Chapter 10 自動車業界の未来動向']}
# {'_id': ObjectId('62a9c97f918df2dec06e263f'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12806-7', 'key': '978-4-297-12806-7', 'title': '図解でわかるカーボンニュートラル燃料～脱炭素を実現する新バイオ燃料技術～', 'price': '2,400円', 'content': ['第1章 CO2削減に対する国内外の動向', '第2章 カーボンニュートラル燃料の導入と生産技術', '第3章 自動車業界でのCO2削減対策の動向', '第4章 バイオ燃料の動向と今後の可能性', '第5章 航空業界のバイオ燃料の取り組み', '第6章 バイオエタノールの新たな用途への展開', '第7章 バイオエタノールの産業化シナリオと政策提言']}
# {'_id': ObjectId('62a9c980918df2dec06e2640'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12794-7', 'key': '978-4-297-12794-7', 'title': '図解即戦力ネットワークのしくみと技術がこれ1冊でしっかりわかる本', 'price': '1,600円', 'content': ['Chapter 1 ネットワークの基本概念を知ろう', 'Chapter 2 データをやり取りするしくみを知ろう', 'Chapter 3 ネットワークの種類と構成を知ろう', 'Chapter 4 インターネットのしくみを知ろう', 'Chapter 5 クラウドのしくみを知ろう', 'Chapter 6 モバイル・無線通信のしくみを知ろう', 'Chapter 7 セキュリティのしくみを知ろう']}
# {'_id': ObjectId('62a9c981918df2dec06e2641'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12802-9', 'key': '978-4-297-12802-9', 'title': '今すぐ使えるかんたんWord＆Excel 2021［Office 2021/Microsoft 365両対応］', 'price': '1,960円', 'content': ['Wordの部', 'Excelの部']}
# {'_id': ObjectId('62a9c983918df2dec06e2642'), 'url': 'https://gihyo.jp/dp/ebook/2022/978-4-297-12871-5', 'key': '978-4-297-12871-5', 'title': 'はたらく微生物', 'price': '2,680円', 'content': ['第1章 微生物ってどんな生き物？', '第2章 食べ物をおいしくする微生物', '第3章 健康に役立つ微生物', '第4章 産業を生む微生物', '第5章 環境をよくする微生物']}
